# %%
# Importação do Pandas
import pandas as pd

# %% [markdown]
# ### Criar DataFrames com base nos Datasets

# %% [markdown]
# ##### Customers

# %%
# Carregamento do dataframe de clientes (customers)
df_customers = pd.read_csv('data/churn_customers.csv')

# %%
# Visualização dos 3 primeiros registros de customers
df_customers.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No

# %%
# Visualização dos 4 últimos registros de customers
df_customers.tail(4)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# Visualização de informações/schema do dataframe de customers
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ##### Services

# %%
# Carregamento do dataframe de serviços (services)
df_services = pd.read_csv('data/churn_services.csv')

# %%
# Visualização dos 3 primeiros registros de services
df_services.head(3)
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No

# %%
# Visualização dos 4 últimos registros de services
df_services.tail(4)
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies
# 7039             Yes
# 7040              No
# 7041              No
# 7042             Yes

# %%
# Visualização de informações/schema do dataframe de services
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %% [markdown]
# ##### Contracts

# %%
# Carregamento do dataframe de contratos (contracts)
df_contracts = pd.read_csv('data/churn_contracts.csv')

# %%
# Visualização dos 3 primeiros registros de contracts
df_contracts.head(3)
# Out:
#    customerID  tenure        Contract PaperlessBilling     PaymentMethod  \
# 0  7590-VHVEG       1  Month-to-month              Yes  Electronic check
# 1  5575-GNVDE      34        One year               No      Mailed check
# 2  3668-QPYBK       2  Month-to-month              Yes      Mailed check
#
#    MonthlyCharges TotalCharges Churn
# 0           29.85        29.85    No
# 1           56.95       1889.5    No
# 2           53.85       108.15   Yes

# %%
# Visualização dos 4 últimos registros de contracts
df_contracts.tail(4)
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 7039    Credit card (automatic)          103.20       7362.9    No
# 7040           Electronic check           29.60       346.45    No
# 7041               Mailed check           74.40        306.6   Yes
# 7042  Bank transfer (automatic)          105.65       6844.5    No

# %%
# Visualização de informações/schema do dataframe de contracts
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# ### Transformação de Dados

# %% [markdown]
# > Coluna "TotalCharges" deveria ser do tipo `float`

# %%
# Transformação da coluna "TotalCharges" para float (abordagem com astype)
try:
    df_contracts['TotalCharges'] = df_contracts['TotalCharges'].astype(float)
except Exception as e:
    print(f'Erro identificado: {e}.')
# Out:
# Erro identificado: could not convert string to float: ' '.

# %% [markdown]
# ##### Disclaimer

# %%
# Exemplo de quando o astype funciona
df = pd.DataFrame(
    {
        'id_venda': [1, 2, 3],
        'valor_venda': ['100.58', '199.99', '335.42']
    }
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venda     3 non-null      int64
#  1   valor_venda  3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
# Conversão da coluna "valor_venda" para float
df['valor_venda'] = df['valor_venda'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venda     3 non-null      int64
#  1   valor_venda  3 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 180.0 bytes

# %%
df
# Out:
#    id_venda  valor_venda
# 0         1       100.58
# 1         2       199.99
# 2         3       335.42

# %% [markdown]
# ##### 2ª alternativa de transformação da coluna para `float`

# %%
# Transformação da coluna "TotalCharges" para float (abordagem com to_numeric)
try:
    df_contracts['TotalCharges'] = pd.to_numeric(df_contracts['TotalCharges'])
except Exception as e:
    print(f'Erro identificado: {e}.')
# Out:
# Erro identificado: Unable to parse string " " at position 488.

# %%
# Visualização do valor da linha 488 e da coluna "TotalCharges"
df_contracts.loc[488, 'TotalCharges']
# Out:
# ' '

# %% [markdown]
# ##### 3ª alternativa

# %%
# Transformação da coluna "TotalCharges" para float (abordagem com to_numeric com parâmetro errors='coerce')
df_contracts['TotalCharges'] = pd.to_numeric(df_contracts['TotalCharges'], errors='coerce')

# %%
# Visualização da linha 488 do dataframe de contratos
df_contracts.loc[488]
# Out:
# customerID                         4472-LVYGI
# tenure                                      0
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges                              NaN
# Churn                                      No
# Name: 488, dtype: object

# %%
# Filtro para identificar registros com valores nulos na coluna "TotalCharges"
df_contracts[df_contracts['TotalCharges'].isnull()]
# Out:
#       customerID  tenure  Contract PaperlessBilling  \
# 488   4472-LVYGI       0  Two year              Yes
# 753   3115-CZMZD       0  Two year               No
# 936   5709-LVOEQ       0  Two year               No
# 1082  4367-NUYAO       0  Two year               No
# 1340  1371-DWPAZ       0  Two year               No
# 3331  7644-OMVMY       0  Two year               No
# 3826  3213-VVOLG       0  Two year               No
# 4380  2520-SGTTA       0  Two year               No
# 5218  2923-ARZLG       0  One year              Yes
# 6670  4075-WKNIU       0  Two year               No
# 6754  2775-SEFEE       0  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges Churn
# 488   Bank transfer (automatic)           52.55           NaN    No
# 753                Mailed check           20.25           NaN    No
# 936                Mailed check           80.85           NaN    No
# 1082               Mailed check           25.75           NaN    No
# 1340    Credit card (automatic)           56.05           NaN    No
# 3331               Mailed check           19.85           NaN    No
# 3826               Mailed check           25.35           NaN    No
# 4380               Mailed check           20.00           NaN    No
# 5218               Mailed check           19.70           NaN    No
# 6670               Mailed check           73.35           NaN    No
# 6754  Bank transfer (automatic)           61.90           NaN    No

# %% [markdown]
# > Após a transformação do tipo da coluna "TotalCharges", foi identificado 11 valores nulos

# %% [markdown]
# ### Renomear colunas

# %%
# Visualização dos nomes das colunas de customers
df_customers.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents'], dtype='object')

# %%
# Renomeação da coluna SeniorCitizen para Above65yo
df_customers.rename(columns={'SeniorCitizen': 'Above65yo'}) # Sem o parâmetro inplace a alteração não é persistida
# Out:
#       customerID  gender  Above65yo Partner Dependents
# 0     7590-VHVEG  Female          0     Yes         No
# 1     5575-GNVDE    Male          0      No         No
# 2     3668-QPYBK    Male          0      No         No
# 3     7795-CFOCW    Male          0      No         No
# 4     9237-HQITU  Female          0      No         No
# ...          ...     ...        ...     ...        ...
# 7038  6840-RESVB    Male          0     Yes        Yes
# 7039  2234-XADUH  Female          0     Yes        Yes
# 7040  4801-JZAZL  Female          0     Yes        Yes
# 7041  8361-LTMKD    Male          1     Yes         No
# 7042  3186-AJIEK    Male          0      No         No
#
# [7043 rows x 5 columns]

# %%
# Alteração não persistida
df_customers.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No

# %%
# Criação de um novo dataframe com a coluna renomeada
df_customers_renamed = df_customers.rename(columns={'SeniorCitizen': 'Above65yo'})

# %%
# Visualização da estrutura do novo dataframe
df_customers_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Aplicação da renomeação persistida no próprio dataframe
df_customers.rename(columns={'SeniorCitizen': 'Above65yo'}, inplace=True)

# %%
# Visualização da estrutura do dataframe após a renomeação persistida (com Above65yo)
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Renomeação usando lista (modificar todos os nomes de colunas)
df_customers.columns = ['IDCliente', 'Genero', 'Mais65Anos', 'TemParceiro', 'TemDependentes']

# %%
# Visualização da estrutura do dataframe após a renomeação persistida (com todas as colunas renomeadas)
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   object
#  1   Genero          7043 non-null   object
#  2   Mais65Anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   object
#  4   TemDependentes  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ### Unificar DataFrames

# %%
# Contagem da quantidade de linhas do dataframe de customers
len(df_customers)
# Out:
# 7043

# %%
# Contagem da quantidade de linhas do dataframe de services
len(df_services)
# Out:
# 7043

# %%
# Contagem da quantidade de linhas do dataframe de contracts
len(df_contracts)
# Out:
# 7043

# %%
# Renomeação da coluna "customerID" para "IDCliente" no dataframe de services
df_services.rename(columns={'customerID': 'IDCliente'}, inplace=True)

# %%
# Visualização da estrutura do dataframe de services após a renomeação
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Unificação dos dataframes de customers e services
df_customers_services = df_customers.merge(df_services, on='IDCliente')

# %%
# Visualização da estrutura do dataframe unificado
df_customers_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 770.5+ KB

# %%
# Visualização dos 3 primeiros registros do dataframe unificado
df_customers_services.head(3)
# Out:
#     IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies
# 0               No          No          No              No
# 1              Yes          No          No              No
# 2               No          No          No              No

# %%
# Unificação dos dataframes de customers_services e contracts (com nomes de colunas diferentes)
df_churn_temp = df_customers_services.merge(df_contracts, left_on='IDCliente', right_on='customerID')

# %%
# Visualização da estrutura do dataframe resultante dos 3 primeiros
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  MonthlyCharges    7043 non-null   float64
#  20  TotalCharges      7032 non-null   float64
#  21  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
# Unificação dos 3 dataframes (customers, services e contracts) em um único dataframe
df_churn = df_customers.merge(df_services, on='IDCliente') \
           .merge(df_contracts, left_on='IDCliente', right_on='customerID')

# %%
# Visualização da estrutura do dataframe resultante
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  MonthlyCharges    7043 non-null   float64
#  20  TotalCharges      7032 non-null   float64
#  21  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
# Remoção da coluna "customerID" do dataframe de churn
df_churn.drop('customerID', axis=1, inplace=True) # axis=1 indica que a remoção é de uma coluna e axis=0 indicaria linha

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Detecção de valores ausentes

# %%
# Detecção de valores ausentes no dataframe de churn
df_churn.isna().sum()
# Out:
# IDCliente            0
# Genero               0
# Mais65Anos           0
# TemParceiro          0
# TemDependentes       0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Detecção de valores ausentes em uma coluna específica
print(df_churn.TotalCharges.isna().sum())
# Out:
# 11

# %%
# Detecção de quantas linhas possuem pelo menos um valor ausente
df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup  ...          TechSupport          StreamingTV  \
# 488                    No  ...                  Yes                  Yes
# 753   No internet service  ...  No internet service  No internet service
# 936                   Yes  ...                   No                  Yes
# 1082  No internet service  ...  No internet service  No internet service
# 1340                  Yes  ...                  Yes                  Yes
# 3331  No internet service  ...  No internet service  No internet service
# 3826  No internet service  ...  No internet service  No internet service
# 4380  No internet service  ...  No internet service  No internet service
# 5218  No internet service  ...  No internet service  No internet service
# 6670                  Yes  ...                  Yes                  Yes
# 6754                  Yes  ...                  Yes                   No
#
#           StreamingMovies tenure  Contract PaperlessBilling  \
# 488                    No      0  Two year              Yes
# 753   No internet service      0  Two year               No
# 936                   Yes      0  Two year               No
# 1082  No internet service      0  Two year               No
# 1340                   No      0  Two year               No
# 3331  No internet service      0  Two year               No
# 3826  No internet service      0  Two year               No
# 4380  No internet service      0  Two year               No
# 5218  No internet service      0  One year              Yes
# 6670                   No      0  Two year               No
# 6754                   No      0  Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 488   Bank transfer (automatic)          52.55           NaN     No
# 753                Mailed check          20.25           NaN     No
# 936                Mailed check          80.85           NaN     No
# 1082               Mailed check          25.75           NaN     No
# 1340    Credit card (automatic)          56.05           NaN     No
# 3331               Mailed check          19.85           NaN     No
# 3826               Mailed check          25.35           NaN     No
# 4380               Mailed check          20.00           NaN     No
# 5218               Mailed check          19.70           NaN     No
# 6670               Mailed check          73.35           NaN     No
# 6754  Bank transfer (automatic)          61.90           NaN     No
#
# [11 rows x 21 columns]

# %%
# Detecção de quantas colunas possuem pelo menos um valor ausente
df_churn.isna().any()
# Out:
# IDCliente           False
# Genero              False
# Mais65Anos          False
# TemParceiro         False
# TemDependentes      False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# tenure              False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges         True
# Churn               False
# dtype: bool

# %% [markdown]
# ## Remoção de valores ausentes

# %%
# Remoção da coluna "TotalCharges" do dataframe de churn
df_churn.drop(columns='TotalCharges', axis=1)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges Churn
# 0              29.85    No
# 1              56.95    No
# 2              53.85   Yes
# 3              42.30    No
# 4              70.70   Yes
# ...              ...   ...
# 7038           84.80    No
# 7039          103.20    No
# 7040           29.60    No
# 7041           74.40   Yes
# 7042          105.65    No
#
# [7043 rows x 20 columns]

# %%
# Remoção de colunas com valores ausentes
df_churn.dropna(axis=1)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges Churn
# 0              29.85    No
# 1              56.95    No
# 2              53.85   Yes
# 3              42.30    No
# 4              70.70   Yes
# ...              ...   ...
# 7038           84.80    No
# 7039          103.20    No
# 7040           29.60    No
# 7041           74.40   Yes
# 7042          105.65    No
#
# [7043 rows x 20 columns]

# %%
# Remoção de colunas se todas as linhas possuírem valores ausentes
df_churn.dropna(axis=1, how='all')
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# 1                   No             DSL            Yes           No  ...
# 2                   No             DSL            Yes          Yes  ...
# 3     No phone service             DSL            Yes           No  ...
# 4                   No     Fiber optic             No           No  ...
# ...                ...             ...            ...          ...  ...
# 7038               Yes             DSL            Yes           No  ...
# 7039               Yes     Fiber optic             No          Yes  ...
# 7040  No phone service             DSL            Yes           No  ...
# 7041               Yes     Fiber optic             No           No  ...
# 7042                No     Fiber optic            Yes           No  ...
#
#      TechSupport StreamingTV StreamingMovies tenure        Contract  \
# 0             No          No              No      1  Month-to-month
# 1             No          No              No     34        One year
# 2             No          No              No      2  Month-to-month
# 3            Yes          No              No     45        One year
# 4             No          No              No      2  Month-to-month
# ...          ...         ...             ...    ...             ...
# 7038         Yes         Yes             Yes     24        One year
# 7039          No         Yes             Yes     72        One year
# 7040          No          No              No     11  Month-to-month
# 7041          No          No              No      4  Month-to-month
# 7042         Yes         Yes             Yes     66        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95       1889.50
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [7043 rows x 21 columns]

# %%
# Remoção das linhas com algum valor ausente
df_churn.dropna(axis=0)
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# 1                   No             DSL            Yes           No  ...
# 2                   No             DSL            Yes          Yes  ...
# 3     No phone service             DSL            Yes           No  ...
# 4                   No     Fiber optic             No           No  ...
# ...                ...             ...            ...          ...  ...
# 7038               Yes             DSL            Yes           No  ...
# 7039               Yes     Fiber optic             No          Yes  ...
# 7040  No phone service             DSL            Yes           No  ...
# 7041               Yes     Fiber optic             No           No  ...
# 7042                No     Fiber optic            Yes           No  ...
#
#      TechSupport StreamingTV StreamingMovies tenure        Contract  \
# 0             No          No              No      1  Month-to-month
# 1             No          No              No     34        One year
# 2             No          No              No      2  Month-to-month
# 3            Yes          No              No     45        One year
# 4             No          No              No      2  Month-to-month
# ...          ...         ...             ...    ...             ...
# 7038         Yes         Yes             Yes     24        One year
# 7039          No         Yes             Yes     72        One year
# 7040          No          No              No     11  Month-to-month
# 7041          No          No              No      4  Month-to-month
# 7042         Yes         Yes             Yes     66        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95       1889.50
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [7032 rows x 21 columns]

# %%
# Remoção de linhas com todos os valores ausentes
df_churn.dropna(axis=0, how='all')
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# 1                   No             DSL            Yes           No  ...
# 2                   No             DSL            Yes          Yes  ...
# 3     No phone service             DSL            Yes           No  ...
# 4                   No     Fiber optic             No           No  ...
# ...                ...             ...            ...          ...  ...
# 7038               Yes             DSL            Yes           No  ...
# 7039               Yes     Fiber optic             No          Yes  ...
# 7040  No phone service             DSL            Yes           No  ...
# 7041               Yes     Fiber optic             No           No  ...
# 7042                No     Fiber optic            Yes           No  ...
#
#      TechSupport StreamingTV StreamingMovies tenure        Contract  \
# 0             No          No              No      1  Month-to-month
# 1             No          No              No     34        One year
# 2             No          No              No      2  Month-to-month
# 3            Yes          No              No     45        One year
# 4             No          No              No      2  Month-to-month
# ...          ...         ...             ...    ...             ...
# 7038         Yes         Yes             Yes     24        One year
# 7039          No         Yes             Yes     72        One year
# 7040          No          No              No     11  Month-to-month
# 7041          No          No              No      4  Month-to-month
# 7042         Yes         Yes             Yes     66        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95       1889.50
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [7043 rows x 21 columns]

# %% [markdown]
# ## Imputação de valores ausentes

# %%
# Preenchimento de valores ausentes com ZERO
df_churn.fillna(0).query('TotalCharges == 0')
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup  ...          TechSupport          StreamingTV  \
# 488                    No  ...                  Yes                  Yes
# 753   No internet service  ...  No internet service  No internet service
# 936                   Yes  ...                   No                  Yes
# 1082  No internet service  ...  No internet service  No internet service
# 1340                  Yes  ...                  Yes                  Yes
# 3331  No internet service  ...  No internet service  No internet service
# 3826  No internet service  ...  No internet service  No internet service
# 4380  No internet service  ...  No internet service  No internet service
# 5218  No internet service  ...  No internet service  No internet service
# 6670                  Yes  ...                  Yes                  Yes
# 6754                  Yes  ...                  Yes                   No
#
#           StreamingMovies tenure  Contract PaperlessBilling  \
# 488                    No      0  Two year              Yes
# 753   No internet service      0  Two year               No
# 936                   Yes      0  Two year               No
# 1082  No internet service      0  Two year               No
# 1340                   No      0  Two year               No
# 3331  No internet service      0  Two year               No
# 3826  No internet service      0  Two year               No
# 4380  No internet service      0  Two year               No
# 5218  No internet service      0  One year              Yes
# 6670                   No      0  Two year               No
# 6754                   No      0  Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 488   Bank transfer (automatic)          52.55           0.0     No
# 753                Mailed check          20.25           0.0     No
# 936                Mailed check          80.85           0.0     No
# 1082               Mailed check          25.75           0.0     No
# 1340    Credit card (automatic)          56.05           0.0     No
# 3331               Mailed check          19.85           0.0     No
# 3826               Mailed check          25.35           0.0     No
# 4380               Mailed check          20.00           0.0     No
# 5218               Mailed check          19.70           0.0     No
# 6670               Mailed check          73.35           0.0     No
# 6754  Bank transfer (automatic)          61.90           0.0     No
#
# [11 rows x 21 columns]

# %%
# Preencimento de valores padrões a depender do tipo de dado
df_churn.fillna(value={
    'TotalCharges': 0,
    'Genero': 'Não Declarado'
}).query('TotalCharges == 0')
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup  ...          TechSupport          StreamingTV  \
# 488                    No  ...                  Yes                  Yes
# 753   No internet service  ...  No internet service  No internet service
# 936                   Yes  ...                   No                  Yes
# 1082  No internet service  ...  No internet service  No internet service
# 1340                  Yes  ...                  Yes                  Yes
# 3331  No internet service  ...  No internet service  No internet service
# 3826  No internet service  ...  No internet service  No internet service
# 4380  No internet service  ...  No internet service  No internet service
# 5218  No internet service  ...  No internet service  No internet service
# 6670                  Yes  ...                  Yes                  Yes
# 6754                  Yes  ...                  Yes                   No
#
#           StreamingMovies tenure  Contract PaperlessBilling  \
# 488                    No      0  Two year              Yes
# 753   No internet service      0  Two year               No
# 936                   Yes      0  Two year               No
# 1082  No internet service      0  Two year               No
# 1340                   No      0  Two year               No
# 3331  No internet service      0  Two year               No
# 3826  No internet service      0  Two year               No
# 4380  No internet service      0  Two year               No
# 5218  No internet service      0  One year              Yes
# 6670                   No      0  Two year               No
# 6754                   No      0  Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 488   Bank transfer (automatic)          52.55           0.0     No
# 753                Mailed check          20.25           0.0     No
# 936                Mailed check          80.85           0.0     No
# 1082               Mailed check          25.75           0.0     No
# 1340    Credit card (automatic)          56.05           0.0     No
# 3331               Mailed check          19.85           0.0     No
# 3826               Mailed check          25.35           0.0     No
# 4380               Mailed check          20.00           0.0     No
# 5218               Mailed check          19.70           0.0     No
# 6670               Mailed check          73.35           0.0     No
# 6754  Bank transfer (automatic)          61.90           0.0     No
#
# [11 rows x 21 columns]

# %%
# Preenchimento de valores ausentes com a média da coluna
media_TotalCharges = df_churn['TotalCharges'].mean()

df_churn.fillna(value={'TotalCharges': media_TotalCharges}).query('TotalCharges == @media_TotalCharges')
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup  ...          TechSupport          StreamingTV  \
# 488                    No  ...                  Yes                  Yes
# 753   No internet service  ...  No internet service  No internet service
# 936                   Yes  ...                   No                  Yes
# 1082  No internet service  ...  No internet service  No internet service
# 1340                  Yes  ...                  Yes                  Yes
# 3331  No internet service  ...  No internet service  No internet service
# 3826  No internet service  ...  No internet service  No internet service
# 4380  No internet service  ...  No internet service  No internet service
# 5218  No internet service  ...  No internet service  No internet service
# 6670                  Yes  ...                  Yes                  Yes
# 6754                  Yes  ...                  Yes                   No
#
#           StreamingMovies tenure  Contract PaperlessBilling  \
# 488                    No      0  Two year              Yes
# 753   No internet service      0  Two year               No
# 936                   Yes      0  Two year               No
# 1082  No internet service      0  Two year               No
# 1340                   No      0  Two year               No
# 3331  No internet service      0  Two year               No
# 3826  No internet service      0  Two year               No
# 4380  No internet service      0  Two year               No
# 5218  No internet service      0  One year              Yes
# 6670                   No      0  Two year               No
# 6754                   No      0  Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges  Churn
# 488   Bank transfer (automatic)          52.55   2283.300441     No
# 753                Mailed check          20.25   2283.300441     No
# 936                Mailed check          80.85   2283.300441     No
# 1082               Mailed check          25.75   2283.300441     No
# 1340    Credit card (automatic)          56.05   2283.300441     No
# 3331               Mailed check          19.85   2283.300441     No
# 3826               Mailed check          25.35   2283.300441     No
# 4380               Mailed check          20.00   2283.300441     No
# 5218               Mailed check          19.70   2283.300441     No
# 6670               Mailed check          73.35   2283.300441     No
# 6754  Bank transfer (automatic)          61.90   2283.300441     No
#
# [11 rows x 21 columns]

# %% [markdown]
# ## Análise univariada

# %% [markdown]
# Hipótese 1: A faixa etária do cliente tem uma forte associação com o churn

# %%
# Verificação de valores únicos em uma coluna
df_churn['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Contaagem de clientes usando a variável churn
df_churn['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Porcentagem de clientes que cancelaram o serviço e que não cancelaram
df_churn['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
# Plotagem da distribuição de clientes que cancelaram o serviço e que não cancelaram
ax = df_churn['Churn'].value_counts().plot(kind='bar', title='Distribuição de clientes churn', xlabel='Churn', ylabel='Quantidade', color=['lightgreen', 'orange'], figsize=(10, 7))

# Adição de rótulos nos gráficos
ax.bar_label(ax.containers[0], label_type='edge', padding=3)
# Out:
# [Text(0, 3, '5174'), Text(0, 3, '1869')]

# %%
# Plotagem da distribuição de clientes que cancelaram o serviço e que não cancelaram
ax = df_churn['Churn'].value_counts(normalize=True).plot(kind='bar', title='Distribuição de clientes churn', xlabel='Churn', ylabel='Quantidade', color=['lightgreen', 'orange'], figsize=(10, 7))

# Adição de rótulos nos gráficos
ax.bar_label(ax.containers[0], label_type='edge', padding=3)
# Out:
# [Text(0, 3, '0.73463'), Text(0, 3, '0.26537')]

# %%
# Identificação dos tipos de contratos existentes
df_churn['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Plotagerm da distribuição de tipos de contratos
ax = df_churn['Contract'].value_counts().plot(kind='bar', title='Distribuição de tipos de contratos', xlabel='Tipo de contrato', ylabel='Quantidade', color=['lightblue', 'lightgreen', 'orange'], figsize=(10, 7))

# Adição de rótulos nos gráficos
ax.bar_label(ax.containers[0], label_type='edge', padding=3)
# Out:
# [Text(0, 3, '3875'), Text(0, 3, '1695'), Text(0, 3, '1473')]

# %%
# Plotagerm da distribuição de tipos de contratos
ax = df_churn['Contract'].value_counts(normalize=True).plot(kind='bar', title='Distribuição de tipos de contratos', xlabel='Tipo de contrato', ylabel='Quantidade', color=['lightblue', 'lightgreen', 'orange'], figsize=(10, 7))

# Adição de rótulos nos gráficos
ax.bar_label(ax.containers[0], label_type='edge', padding=3)
# Out:
# [Text(0, 3, '0.550192'), Text(0, 3, '0.240664'), Text(0, 3, '0.209144')]

# %%
# Plotagerm da distribuição de tipos de contratos para clientes que cancelaram
ax = df_churn.query('Churn == "Yes"')['Contract'].value_counts(normalize=True).plot(kind='bar', title='Distribuição de tipos de contratos', xlabel='Tipo de contrato', ylabel='Quantidade', color=['lightblue', 'lightgreen', 'orange'], figsize=(10, 7))

# Adição de rótulos nos gráficos
ax.bar_label(ax.containers[0], label_type='edge', padding=3)
# Out:
# [Text(0, 3, '0.8855'), Text(0, 3, '0.0888175'), Text(0, 3, '0.0256822')]

# %% [markdown]
# Hipótese 2: Um cliente com menos de 6 meses de contrato é mais propenso ao churn

# %%
# Distribuição da coluna "tenure" (histograma)
ax = df_churn['tenure'].plot(kind='hist', title='Distribuição da coluna "tenure" (meses de contrato)', xlabel='Tenure', ylabel='Quantidade', color='lightblue', figsize=(10, 7))

# %% [markdown]
# > A variável "tempo de contrato" (tenure) não apresenta uma distribuição do normal, visualmente
# - A grande parte dos valores se concentram nos extremos, ou seja, contratos com poucos meses de ativação e contratos longos, acima, aproximadamente, dos 65 meses

# %%
# Histograma do MonthlyCharges
ax = df_churn['MonthlyCharges'].plot(kind='hist', title='Distribuição da coluna "MonthlyCharges" (mensalidade)', xlabel='MonthlyCharges', ylabel='Quantidade', color='lightgreen', figsize=(10, 7))

# %%
# Medidas de posição da coluna "tenure" (tempo de contrato)
df_churn['tenure'].describe().loc[['mean', '50%', 'std']]
# Out:
# mean    32.371149
# 50%     29.000000
# std     24.559481
# Name: tenure, dtype: float64

# %%
# Moda da coluna "tenure" (tempo de contrato)
print(df_churn['tenure'].mode().loc[0])
# Out:
# 1

# %%
# Coeficiente de variação da coluna "tenure" (tempo de contrato)
coef_var = df_churn['tenure'].std() / df_churn['tenure'].mean() * 100
print(coef_var)
# Out:
# 75.86842617906674

# %% [markdown]
# Hipótese 3: Cliente com contrato mensal é mais propenso ao churn

# %%
# Quantos clientes possuem 1 mês de contrato (tenure)
df_churn[df_churn['tenure'] == 1].shape[0] # ou len(df_churn[df_churn['tenure'] == 1])
# Out:
# 613

# %%
# Quantos clientes possuem 1 mês de contrato (tenure) em porcentagem
len(df_churn[df_churn['tenure'] == 1]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
# Quantos clientes têm 1 mês a 6 meses de contrato
len(df_churn.query('tenure >= 1 and tenure <= 6'))
# Out:
# 1470

# %%
# Quantos clientes têm menos 6 meses de contrato e são do sexo masculino
len(df_churn.query('tenure <= 6 and Genero == "Male"'))
# Out:
# 746

# %%
# Apresentação da quantidade de clientes por tempo de contrato (tenure) - top 5
df_churn['tenure'].value_counts().loc[:4] # ou df_churn['tenure'].groupby(df_churn['tenure']).count().sort_values(ascending=False).head()
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
# Name: count, dtype: int64

# %%
# Representação gráfica da quantidade de clientes por tempo de contrato (tenure) - top 5
ax = df_churn['tenure'].value_counts().head().plot(kind='bar', title='Top 5 - Distribuição de clientes por tempo de contrato', xlabel='Tenure', ylabel='Quantidade', color='#123456', figsize=(10, 7), rot=-0)

# %% [markdown]
# ## Análise bivariada

# %% [markdown]
# Hipótese 1: Clientes com contrato do tipo mensal são mais propensos ao `churn`

# %%
# Construir tabela de contingência entre as variáveis "Churn" e "Contract"
pd.crosstab(df_churn['Churn'], df_churn['Contract'], margins=True, margins_name='Total')
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
# Construir tabela de contingência entre as variáveis "Churn" e "Contract" (porcentagens)
pd.crosstab(df_churn['Churn'], df_churn['Contract'], normalize=True, margins=True, margins_name='Total') * 100
# Out:
# Contract  Month-to-month   One year   Two year       Total
# Churn
# No             31.520659  18.557433  23.384921   73.463013
# Yes            23.498509   2.356950   0.681528   26.536987
# Total          55.019168  20.914383  24.066449  100.000000

# %%
# Construir tabela de contingência entre as variáveis "Churn" e "Contract" (porcentagens) por coluna
pd.crosstab(df_churn['Churn'], df_churn['Contract'], normalize='columns', margins=True, margins_name='Total') * 100
# Out:
# Contract  Month-to-month   One year   Two year      Total
# Churn
# No             57.290323  88.730482  97.168142  73.463013
# Yes            42.709677  11.269518   2.831858  26.536987

# %% [markdown]
# > A maior proporção de churn está em clientes com contrato mensal (42,71% deixam de ser clientes frente a 11,27% e  e 2,83% nos contratos anual e bianual, respectivamente)

# %% [markdown]
# ##### Avaliar a correlação entre 2 variáveis categóricas (qualitativas)

# %%
# Executar um teste de hipótese chamado Chi-Square ou Qui-Quadrado de Pearson. Num teste de hipótese, 2 hipóteses são formuladas:
# A hipótese nula (H0): as variáveis são independentes
# E a hipótese complementar (H1): as variáveis são dependentes

# O teste serve para confirmar ou rejeitar a hipótese nula
# Se o p-valor for menor que 0.05, rejeitamos a hipótese nula e concluímos que as variáveis são dependentes

# Gerar um DataFrame com a tabela de contingência
df_crosstab_churn_contract = pd.crosstab(df_churn['Churn'], df_churn['Contract'])

# %%
# Importar a função chi2_contingency do módulo scipy.stats
from scipy.stats import chi2_contingency

# %%
# Calcular os scores do teste de hipótese e p-valor
chi_score_churn_contract = chi2_contingency(df_crosstab_churn_contract)
chi_score_churn_contract
# Out:
# Chi2ContingencyResult(statistic=1184.5965720837926, pvalue=5.863038300673391e-258, dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
# Criando 2 séries com os valores de score e p-valor
chi_score = pd.Series(chi_score_churn_contract[0], name='Score')
p_value = pd.Series(chi_score_churn_contract[1], name='P-Value')

# %%
# Apresentação de números com decimais sem notação científica
pd.set_option('display.float_format', lambda x: '%.30f' % x)

# %%
# Criação do DataFrame com os resultados do teste de hipótese
df_chi_score_churn_contract = pd.DataFrame([chi_score, p_value], index=['Score', 'P-Value']).T
df_chi_score_churn_contract
# Out:
#                                 Score                          P-Value
# 0 1184.596572083792580087902024388313 0.000000000000000000000000000000

# %% [markdown]
# > Diante do valor de p-valor (< 0.05), rejeitamos a hipótese nula e as variáveis `Chun` e `Contract` não são independentes. E pelo valor alto de Score (Qui-quadrado), elas possuem forte correlação

# %% [markdown]
# ##### Avaliar a correlação entre uma variável qualitativa e quantitativa

# %% [markdown]
# Usar-se-á o mesmo teste de Chi-Square, mas transformar-se-á a variável quantitativa em qualitativa

# %% [markdown]
# Hipótese: clientes com menos de 6 meses de contrato têm maior probabilidade de cancelamento

# %%
# Criação de uma coluna com base numa condição (TempoMenor6Meses)
import numpy as np

df_churn['TempoMenor6Meses'] = np.where(df_churn['tenure'] < 6, 'Yes', 'No')

# %%
# Checar o dataframe com a nova coluna
df_churn.head()
# Out:
#     IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# 0          No              No      1  Month-to-month               Yes
# 1          No              No     34        One year                No
# 2          No              No      2  Month-to-month               Yes
# 3          No              No     45        One year                No
# 4          No              No      2  Month-to-month               Yes
#
#                PaymentMethod                    MonthlyCharges  \
# 0           Electronic check 29.850000000000001421085471520200
# 1               Mailed check 56.950000000000002842170943040401
# 2               Mailed check 53.850000000000001421085471520200
# 3  Bank transfer (automatic) 42.299999999999997157829056959599
# 4           Electronic check 70.700000000000002842170943040401
#
#                          TotalCharges  Churn  TempoMenor6Meses
# 0   29.850000000000001421085471520200     No               Yes
# 1 1889.500000000000000000000000000000     No                No
# 2  108.150000000000005684341886080801    Yes               Yes
# 3 1840.750000000000000000000000000000     No                No
# 4  151.650000000000005684341886080801    Yes               Yes
#
# [5 rows x 22 columns]

# %%
# Gerar a tabela de contingência entre as variáveis "Churn" e "TempoMenor6Meses"
df_crosstab_churn_tenure = pd.crosstab(df_churn['Churn'], df_churn['TempoMenor6Meses'])

# %%
# Calcular os scores do teste de hipótese e p-valor
chi_score_churn_tenure = chi2_contingency(df_crosstab_churn_tenure)

# %%
# Criação de 2 séries com os valores de score e p-valor
chi_score_tenure = pd.Series(chi_score_churn_tenure[0], name='Score')
p_value_tenure = pd.Series(chi_score_churn_tenure[1], name='P-Value')

# %%
# Criação do dataframe com os resultados do teste de hipótese
df_chi_score_churn_tenure = pd.DataFrame([chi_score_tenure, p_value_tenure], index=['Score', 'P-Value']).T
df_chi_score_churn_tenure
# Out:
#                                Score                          P-Value
# 0 669.721615828710241657972801476717 0.000000000000000000000000000000

# %% [markdown]
# > Como o p-valor é menor que 0.05, rejeitamos a hipótese nula e concluímos que as variáveis são dependentes. Porém, o score é baixo, indicando que a relação entre Churn e TempoMenor6Meses é mais fraca que a relação entre Churn e Contract

# %% [markdown]
# ##### Correlação entre 2 variáveis numéricas

# %% [markdown]
# Hipótese: quanto mais tempo de contrato maior o valor pago

# %%
# Correlação entre as variáveis Tenure e TotalCharges - Pearson
pd.set_option('display.float_format', lambda x: '%.4f' % x)
df_churn[['tenure', 'TotalCharges']].corr()
# Out:
#               tenure  TotalCharges
# tenure        1.0000        0.8259
# TotalCharges  0.8259        1.0000

# %%
# Correlação entre as variáveis Tenure e TotalCharges - Spearman
df_churn[['tenure', 'TotalCharges']].corr(method='spearman')
# Out:
#               tenure  TotalCharges
# tenure        1.0000        0.8892
# TotalCharges  0.8892        1.0000

# %% [markdown]
# > Há uma forte correlação entre Tenure e TotalCharges (usando métodos estatísticos de correlação)

# %%
# Apresentação de gráfico de dispersão entre as variáveis Tenure e TotalCharges
ax = df_churn.plot(kind='scatter', x='tenure', y='TotalCharges', title='Dispersão entre Tenure e TotalCharges', xlabel='Tenure', ylabel='TotalCharges', color='lightblue', figsize=(16, 7))

# %% [markdown]
# Desafio 1: validar a hipótese de que a faixa etária do cliente tem uma forte associação com o Churn

# %%
# Com np.where(), criar uma variável Churn_numeric que recebe 1 se Churn for Yes e 0 se for No
df_churn['Churn_numeric'] = np.where(df_churn['Churn'] == 'Yes', 1, 0)

# %%
# Avaliação da correlação entre as variáveis Churn_numeric e Above65yo
df_churn[['Churn_numeric', 'Mais65Anos']].corr()
# Out:
#                Churn_numeric  Mais65Anos
# Churn_numeric         1.0000      0.1509
# Mais65Anos            0.1509      1.0000

# %% [markdown]
# > A correlação entre Churn e a idade do cliente (Mais65Anos) é considerada positiva e fraca

# %% [markdown]
# Desafio 2: validar com teste de hipótese se o Contrato Mensal está mais propenso ao Churn

# %%
# Criação de uma nova variável chamada "ContratoMensal" que recebe "Yes" se o contrato for mensal e "No" se não for
df_churn['ContratoMensal'] = np.where(df_churn['Contract'] == 'Month-to-month', "Yes", "No")

# %%
# Criação do teste de hipótese entre as variáveis Churn e ContratoMensal
df_crosstab_churn_monthly = pd.crosstab(df_churn['Churn'], df_churn['ContratoMensal'])
chi_score_churn_monthly = chi2_contingency(df_crosstab_churn_monthly)

chi_score_monthly = pd.Series(chi_score_churn_monthly[0], name='Score')
p_value_monthly = pd.Series(chi_score_churn_monthly[1], name='P-Value')

df_chi_score_churn_monthly = pd.DataFrame([chi_score_monthly, p_value_monthly], index=['Score', 'P-Value']).T
df_chi_score_churn_monthly
# Out:
#       Score  P-Value
# 0 1153.9717   0.0000

# %% [markdown]
# > Como o Score é muito alto e o p-valor é muito baixo, rejeitamos a hipótese nula e concluímos que as variáveis são dependentes. Ou seja, a variável Churn é dependente da variável ContratoMensal

# %% [markdown]
# ## Detecção de outliers (valores atípicos)

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65Anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
#  21  TempoMenor6Meses  7043 non-null   object
#  22  Churn_numeric     7043 non-null   int32
#  23  ContratoMensal    7043 non-null   object
# dtypes: float64(2), int32(1), int64(2), object(19)
# memory usage: 1.3+ MB

# %%
# Remoção das linhas com valores ausentes
df_churn.dropna(axis=0, inplace=True)

# %%
# Visualização da estrutura do dataframe após a remoção de valores ausentes
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7032 non-null   object
#  1   Genero            7032 non-null   object
#  2   Mais65Anos        7032 non-null   int64
#  3   TemParceiro       7032 non-null   object
#  4   TemDependentes    7032 non-null   object
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  tenure            7032 non-null   int64
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
#  21  TempoMenor6Meses  7032 non-null   object
#  22  Churn_numeric     7032 non-null   int32
#  23  ContratoMensal    7032 non-null   object
# dtypes: float64(2), int32(1), int64(2), object(19)
# memory usage: 1.3+ MB

# %%
# Visualização do Boxplot da coluna "TotalCharges"
ax = df_churn['TotalCharges'].plot(kind='box', title='Boxplot da coluna "TotalCharges"', figsize=(16, 9))

# %%
# Visualização do Boxplot da coluna "TotalCharges" agrupado por "Contract"
ax = df_churn.boxplot(column='TotalCharges', by='Contract', figsize=(16, 9))

# %%
# Criação de um dataframe apenas com os clientes com "Contract" igual a "Month-to-month"
df_churn_monthly = df_churn.query('Contract == "Month-to-month"').drop(columns=['Churn_numeric', 'ContratoMensal'])
df_churn_monthly
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 2     3668-QPYBK    Male           0          No             No          Yes
# 4     9237-HQITU  Female           0          No             No          Yes
# 5     9305-CDSKC  Female           0          No             No          Yes
# 6     1452-KIOVK    Male           0          No            Yes          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7033  9767-FFLEM    Male           0          No             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
# 7035  8456-QDAVC    Male           0          No             No          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# 2                   No             DSL            Yes          Yes  ...
# 4                   No     Fiber optic             No           No  ...
# 5                  Yes     Fiber optic             No           No  ...
# 6                  Yes     Fiber optic             No          Yes  ...
# ...                ...             ...            ...          ...  ...
# 7033                No     Fiber optic             No           No  ...
# 7034               Yes     Fiber optic            Yes          Yes  ...
# 7035                No     Fiber optic             No           No  ...
# 7040  No phone service             DSL            Yes           No  ...
# 7041               Yes     Fiber optic             No           No  ...
#
#      StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# 0             No              No      1  Month-to-month               Yes
# 2             No              No      2  Month-to-month               Yes
# 4             No              No      2  Month-to-month               Yes
# 5            Yes             Yes      8  Month-to-month               Yes
# 6            Yes              No     22  Month-to-month               Yes
# ...          ...             ...    ...             ...               ...
# 7033          No              No     38  Month-to-month               Yes
# 7034         Yes              No     67  Month-to-month               Yes
# 7035         Yes              No     19  Month-to-month               Yes
# 7040          No              No     11  Month-to-month               Yes
# 7041          No              No      4  Month-to-month               Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn  \
# 0              Electronic check        29.8500      29.8500     No
# 2                  Mailed check        53.8500     108.1500    Yes
# 4              Electronic check        70.7000     151.6500    Yes
# 5              Electronic check        99.6500     820.5000    Yes
# 6       Credit card (automatic)        89.1000    1949.4000     No
# ...                         ...            ...          ...    ...
# 7033    Credit card (automatic)        69.5000    2625.2500     No
# 7034    Credit card (automatic)       102.9500    6886.2500    Yes
# 7035  Bank transfer (automatic)        78.7000    1495.1000     No
# 7040           Electronic check        29.6000     346.4500     No
# 7041               Mailed check        74.4000     306.6000    Yes
#
#       TempoMenor6Meses
# 0                  Yes
# 2                  Yes
# 4                  Yes
# 5                   No
# 6                   No
# ...                ...
# 7033                No
# 7034                No
# 7035                No
# 7040                No
# 7041               Yes
#
# [3875 rows x 22 columns]

# %%
# Visualização de um histograma para checar a distribuição da coluna "TotalCharges" no dataframe df_churn_monthly
ax = df_churn_monthly['TotalCharges'].plot(kind='hist', title='Histograma da coluna "TotalCharges"', xlabel='TotalCharges', ylabel='Quantidade', color='lightblue', figsize=(16, 9))

# %% [markdown]
# ### Método de Tukey

# %%
# Cálculo do IQR (Interquartile Range) da coluna "TotalCharges"
q1_TotalCharges_monthly = df_churn_monthly['TotalCharges'].quantile(0.25)
q3_TotalCharges_monthly = df_churn_monthly['TotalCharges'].quantile(0.75)
iqr_TotalCharges_monthly = q3_TotalCharges_monthly - q1_TotalCharges_monthly
print(iqr_TotalCharges_monthly)
# Out:
# 1906.4

# %%
# Cálculo dos limites inferior e superior do Boxplot
lower_limit_TotalCharges_monthly = q1_TotalCharges_monthly - 1.5 * iqr_TotalCharges_monthly
upper_limit_TotalCharges_monthly = q3_TotalCharges_monthly + 1.5 * iqr_TotalCharges_monthly

# Limite inferior do Boxplot
print(lower_limit_TotalCharges_monthly)
# Out:
# -2699.5000000000005

# %%
# Limite superior do Boxplot
print(upper_limit_TotalCharges_monthly)
# Out:
# 4926.1

# %%
# Criação de um filtro para identificar outliers
outliers_TotalCharges_monthly = df_churn_monthly.query('TotalCharges < @lower_limit_TotalCharges_monthly or TotalCharges > @upper_limit_TotalCharges_monthly')
outliers_TotalCharges_monthly
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 13    0280-XJGEX    Male           0          No             No          Yes
# 61    1215-FIGMP    Male           0          No             No          Yes
# 93    6067-NGCEU  Female           0          No             No          Yes
# 110   0486-HECZI    Male           0         Yes             No          Yes
# 197   6168-YBYNP    Male           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 6897  2363-BJLSL    Male           0          No             No          Yes
# 6952  6394-MFYNG  Female           0          No             No          Yes
# 6965  7789-CRUVC  Female           1         Yes             No          Yes
# 7023  1035-IPQPU  Female           1         Yes             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 13             Yes     Fiber optic             No          Yes  ...
# 61             Yes     Fiber optic             No          Yes  ...
# 93             Yes     Fiber optic            Yes          Yes  ...
# 110            Yes     Fiber optic            Yes          Yes  ...
# 197            Yes     Fiber optic             No          Yes  ...
# ...            ...             ...            ...          ...  ...
# 6897            No             DSL             No          Yes  ...
# 6952           Yes     Fiber optic             No          Yes  ...
# 6965           Yes     Fiber optic            Yes          Yes  ...
# 7023           Yes     Fiber optic             No          Yes  ...
# 7034           Yes     Fiber optic            Yes          Yes  ...
#
#      StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# 13           Yes             Yes     49  Month-to-month               Yes
# 61           Yes              No     60  Month-to-month               Yes
# 93           Yes             Yes     65  Month-to-month               Yes
# 110          Yes              No     55  Month-to-month               Yes
# 197          Yes             Yes     59  Month-to-month               Yes
# ...          ...             ...    ...             ...               ...
# 6897         Yes             Yes     62  Month-to-month               Yes
# 6952         Yes             Yes     48  Month-to-month               Yes
# 6965          No              No     61  Month-to-month               Yes
# 7023         Yes             Yes     63  Month-to-month               Yes
# 7034         Yes              No     67  Month-to-month               Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn  \
# 13    Bank transfer (automatic)       103.7000    5036.3000    Yes
# 61    Bank transfer (automatic)        89.9000    5450.7000     No
# 93      Credit card (automatic)       111.0500    7107.0000     No
# 110            Electronic check        96.7500    5238.9000    Yes
# 197            Electronic check       111.3500    6519.7500     No
# ...                         ...            ...          ...    ...
# 6897  Bank transfer (automatic)        80.4000    4981.1500     No
# 6952  Bank transfer (automatic)       107.4000    5121.3000    Yes
# 6965    Credit card (automatic)        94.2000    5895.4500     No
# 7023           Electronic check       103.5000    6479.4000     No
# 7034    Credit card (automatic)       102.9500    6886.2500    Yes
#
#       TempoMenor6Meses
# 13                  No
# 61                  No
# 93                  No
# 110                 No
# 197                 No
# ...                ...
# 6897                No
# 6952                No
# 6965                No
# 7023                No
# 7034                No
#
# [200 rows x 22 columns]

# %% [markdown]
# ### Z-Score (usado para distribuição normal)

# %% [markdown]
# Indica quantos desvios padrões um ponto específico de dados está distante da média

# %%
# Z-score para identificar outliers (z-score = (x - mean) / std)
from scipy.stats import zscore

# Cálculo do z-score da coluna "TotalCharges" e tornando os valores absolutos
z_scores_TotalCharges_monthly = np.abs(zscore(df_churn_monthly['TotalCharges']))
z_scores_TotalCharges_monthly
# Out:
# array([0.83003585, 0.78151294, 0.75455577, ..., 0.07798705, 0.63383722,
#        0.65853247])

# %%
# Filtro para identificar outliers com z-score
df_churn_monthly[z_scores_TotalCharges_monthly > 3]
# Out:
#        IDCliente  Genero  Mais65Anos TemParceiro TemDependentes PhoneService  \
# 93    6067-NGCEU  Female           0          No             No          Yes
# 197   6168-YBYNP    Male           0          No             No          Yes
# 339   1343-EHPYB    Male           0         Yes             No          Yes
# 402   0979-PHULV    Male           0         Yes            Yes          Yes
# 445   7752-XUSCI  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 6565  1548-FEHVL    Male           0         Yes             No          Yes
# 6587  7426-GSWPO    Male           1          No             No          Yes
# 6713  4989-LIXVT    Male           1          No             No          Yes
# 7023  1035-IPQPU  Female           1         Yes             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 93             Yes     Fiber optic            Yes          Yes  ...
# 197            Yes     Fiber optic             No          Yes  ...
# 339            Yes     Fiber optic             No          Yes  ...
# 402            Yes     Fiber optic             No           No  ...
# 445            Yes     Fiber optic             No          Yes  ...
# ...            ...             ...            ...          ...  ...
# 6565           Yes     Fiber optic            Yes          Yes  ...
# 6587           Yes     Fiber optic            Yes          Yes  ...
# 6713           Yes     Fiber optic             No          Yes  ...
# 7023           Yes     Fiber optic             No          Yes  ...
# 7034           Yes     Fiber optic            Yes          Yes  ...
#
#      StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# 93           Yes             Yes     65  Month-to-month               Yes
# 197          Yes             Yes     59  Month-to-month               Yes
# 339          Yes             Yes     63  Month-to-month               Yes
# 402          Yes             Yes     69  Month-to-month               Yes
# 445          Yes             Yes     60  Month-to-month               Yes
# ...          ...             ...    ...             ...               ...
# 6565         Yes             Yes     61  Month-to-month               Yes
# 6587         Yes             Yes     64  Month-to-month               Yes
# 6713          No             Yes     68  Month-to-month               Yes
# 7023         Yes             Yes     63  Month-to-month               Yes
# 7034         Yes              No     67  Month-to-month               Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn  \
# 93      Credit card (automatic)       111.0500    7107.0000     No
# 197            Electronic check       111.3500    6519.7500     No
# 339            Electronic check       103.4000    6603.0000    Yes
# 402     Credit card (automatic)        99.4500    7007.6000    Yes
# 445            Electronic check       105.9000    6396.4500    Yes
# ...                         ...            ...          ...    ...
# 6565           Electronic check       106.2000    6375.2000     No
# 6587  Bank transfer (automatic)       103.5000    6548.6500     No
# 6713           Electronic check        95.9000    6503.2000     No
# 7023           Electronic check       103.5000    6479.4000     No
# 7034    Credit card (automatic)       102.9500    6886.2500    Yes
#
#       TempoMenor6Meses
# 93                  No
# 197                 No
# 339                 No
# 402                 No
# 445                 No
# ...                ...
# 6565                No
# 6587                No
# 6713                No
# 7023                No
# 7034                No
#
# [65 rows x 22 columns]

# %% [markdown]
# ## Automatizando a EDA

# %%
# SweetViz - importação
import sweetviz as sv

# SweetViz - criação do relatório
sv_churn_report = sv.analyze(df_churn, target_feat='Churn')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
sv_churn_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(ie,e){&quot;use strict&quot;;var oe=[],r=Object.getPrototypeOf,ae=oe.slice,g=oe.flat?function(e){return oe.flat.call(e)}:function(e){return oe.concat.apply([],e)},s=oe.push,se=oe.indexOf,n={},i=n.toString,ue=n.hasOwnProperty,o=ue.toString,a=o.call(Object),le={},v=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},y=function(e){return null!=e&amp;&amp;e===e.window},C=ie.document,u={type:!0,src:!0,nonce:!0,noModule:!0};function m(e,t,n){var r,i,o=(n=n||C).createElement(&quot;script&quot;);if(o.text=e,t)for(r in u)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function x(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[i.call(e)]||&quot;object&quot;:typeof e}var t=&quot;3.7.1&quot;,l=/HTML$/i,ce=function(e,t){return new ce.fn.init(e,t)};function c(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=x(e);return!v(e)&amp;&amp;!y(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}function fe(e,t){return e.nodeName&amp;&amp;e.nodeName.toLowerCase()===t.toLowerCase()}ce.fn=ce.prototype={jquery:t,constructor:ce,length:0,toArray:function(){return ae.call(this)},get:function(e){return null==e?ae.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=ce.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return ce.each(this,e)},map:function(n){return this.pushStack(ce.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(ae.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(ce.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(ce.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:s,sort:oe.sort,splice:oe.splice},ce.extend=ce.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||v(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(ce.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||ce.isPlainObject(n)?n:{},i=!1,a[t]=ce.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},ce.extend({expando:&quot;jQuery&quot;+(t+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==i.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=ue.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;o.call(n)===a)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){m(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(c(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},text:function(e){var t,n=&quot;&quot;,r=0,i=e.nodeType;if(!i)while(t=e[r++])n+=ce.text(t);return 1===i||11===i?e.textContent:9===i?e.documentElement.textContent:3===i||4===i?e.nodeValue:n},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(c(Object(e))?ce.merge(n,&quot;string&quot;==typeo ...

# %%
# Gerando o HTML do relatório
sv_churn_report.show_html(filepath='report_churn.html', open_browser=True)
# Out:
# Report report_churn.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
